# %%
import os
import cv2  # For image processing
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras import layers, models

# %%
def load_images_from_folder(folder, label, img_size=(256, 256)):
    images = []
    labels = []
    for filename in os.listdir(folder):
        img_path = os.path.join(folder, filename)
        img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)  # Read in grayscale
        if img is not None:
            img = cv2.resize(img, img_size)  # Resize to (150, 150)
            img = img / 255.0  # Normalize between 0 and 1
            images.append(img)
            labels.append(label)
    return np.array(images), np.array(labels)

cats_folder = 'K:\Computer Science\Cat-Dog_Classification\cats'
dogs_folder = 'K:\Computer Science\Cat-Dog_Classification\dogs'

# Load cat and dog images
cat_images, cat_labels = load_images_from_folder(cats_folder, label=0)  # Label for cats is 0
dog_images, dog_labels = load_images_from_folder(dogs_folder, label=1)  # Label for dogs is 1
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\C'
# <>:15: SyntaxWarning: invalid escape sequence '\C'
# <>:14: SyntaxWarning: invalid escape sequence '\C'
# <>:15: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\krish\AppData\Local\Temp\ipykernel_33244\2050935929.py:14: SyntaxWarning: invalid escape sequence '\C'
#   cats_folder = 'K:\Computer Science\Cat-Dog_Classification\cats'
# C:\Users\krish\AppData\Local\Temp\ipykernel_33244\2050935929.py:15: SyntaxWarning: invalid escape sequence '\C'
#   dogs_folder = 'K:\Computer Science\Cat-Dog_Classification\dogs'

# %%
X = np.concatenate((cat_images, dog_images), axis=0)  # Combine cat and dog images
y = np.concatenate((cat_labels, dog_labels), axis=0)  # Combine cat and dog labels

X, y = shuffle(X, y, random_state=42)

X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)
print(X.shape)
# Out:
# (140, 256, 256, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
plt.figure(figsize=(5, 5))
plt.imshow(X_train[0].reshape(256, 256), cmap='gray')
plt.title(f"Sample Image from Dataset (Label: {'Cat' if y_train[0] == 0 else 'Dog'})")
plt.axis('off')
plt.show()

# %%
model = models.Sequential()

model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 1)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(128, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# k:\Computer Science\.venv\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test, y_test)
)
# Out:
# Epoch 1/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 443ms/step - accuracy: 0.5735 - loss: 0.9323 - val_accuracy: 0.4286 - val_loss: 0.7108
# Epoch 2/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.5186 - loss: 0.6944 - val_accuracy: 0.4286 - val_loss: 0.6979
# Epoch 3/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 378ms/step - accuracy: 0.4592 - loss: 0.6965 - val_accuracy: 0.4286 - val_loss: 0.6970
# Epoch 4/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 372ms/step - accuracy: 0.5238 - loss: 0.6927 - val_accuracy: 0.4286 - val_loss: 0.7032
# Epoch 5/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.5030 - loss: 0.6897 - val_accuracy: 0.4286 - val_loss: 0.7065
# Epoch 6/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step - accuracy: 0.5565 - loss: 0.6815 - val_accuracy: 0.5714 - val_loss: 0.6890
# Epoch 7/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 388ms/step - accuracy: 0.7365 - loss: 0.6642 - val_accuracy: 0.5000 - val_loss: 0.7009
# Epoch 8/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - accuracy: 0.7244 - loss: 0.6043 - val_accuracy: 0.5714 - val_loss: 0.7744
# Epoch 9/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - accuracy: 0.7490 - loss: 0.5176 - val_accuracy: 0.5000 - val_loss: 0.7709
# Epoch 10/10
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 368ms/step - accuracy: 0.7292 - loss: 0.4816 - val_accuracy: 0.6429 - val_loss: 1.0965

# %%
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f"Test Loss: {test_loss}, Test Accuracy: {test_acc}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.6429 - loss: 1.0965
# Test Loss: 1.096469521522522, Test Accuracy: 0.6428571343421936

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
def load_and_predict(img_path):
    img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
    img = cv2.resize(img, (256, 256))
    img = img / 255.0
    img = np.expand_dims(img, axis=-1)  # Add the channel dimension
    img = np.expand_dims(img, axis=0)  # Add the batch dimension

    prediction = model.predict(img)

    plt.imshow(img[0].reshape(256, 256), cmap='gray')
    plt.title(f"Prediction: {'Dog' if prediction[0] > 0.5 else 'Cat'}")
    plt.axis('off')
    plt.show()

# %%
load_and_predict('K:\Computer Science\Cat-Dog_Classification\cats\cat_158.jpg')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\krish\AppData\Local\Temp\ipykernel_33244\2645693848.py:1: SyntaxWarning: invalid escape sequence '\C'
#   load_and_predict('K:\Computer Science\Cat-Dog_Classification\cats\cat_158.jpg')

# %%
model.save('cat_dog_classifier.keras')
